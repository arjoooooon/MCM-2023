# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Species_Biodiversity_-_ACE_[ds2769].csv')
df2 = df[df['Name'] == 'Dutch Creek-Elliott Creek']

# %%
df2.head()
# Out:
#       OBJECTID  Hex_ID         HUC12                       Name  SpBioRnkEco  \
# 0            1     100  171003090103  Dutch Creek-Elliott Creek            2
# 206        207     101  171003090103  Dutch Creek-Elliott Creek            2
# 396        397     102  171003090103  Dutch Creek-Elliott Creek            2
# 606        607     103  171003090103  Dutch Creek-Elliott Creek            2
# 9361      9362     144  171003090103  Dutch Creek-Elliott Creek            3
#
#       SpBioWtEco  SpBioRnkSW  BioTrRnkEco  BioTrRnkSW  BioAqRnkSW  ...  \
# 0       0.340206           4          4.0         5.0           3  ...
# 206     0.329657           4          3.0         4.0           3  ...
# 396     0.317662           3          3.0         4.0           3  ...
# 606     0.314016           3          3.0         4.0           3  ...
# 9361    0.348147           4          4.0         5.0           3  ...
#
#       TerrConnRank  TerrClimRank  TerrHabRank  AqHabRank  Eco_Sect  \
# ...
